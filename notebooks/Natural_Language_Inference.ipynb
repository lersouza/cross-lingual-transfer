# %% [markdown]
# ## Environment

# %%
# !nvidia-smi
# Out:
# Mon Aug 17 17:27:25 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Setup

# %%
# !pip install --upgrade future --quiet
# !pip install --upgrade git+git://github.com/lersouza/cross-lingual-transfer.git#egg=crosslangt --quiet
# Out:
#      |████████████████████████████████| 829kB 10.7MB/s
#   Building wheel for future (setup.py) ... done
#      |████████████████████████████████| 317kB 10.5MB/s
#      |████████████████████████████████| 675kB 33.5MB/s
#      |████████████████████████████████| 276kB 43.8MB/s
#      |████████████████████████████████| 890kB 37.8MB/s
#      |████████████████████████████████| 1.1MB 35.5MB/s
#      |████████████████████████████████| 3.8MB 41.5MB/s
#   Building wheel for crosslangt (setup.py) ... done
#   Building wheel for PyYAML (setup.py) ... done
#   Building wheel for sacremoses (setup.py) ... done

# %% [markdown]
# ## Experiments

# %%
import os
import random
import torch

from collections import Counter
from crosslangt.nli.experiments import run_nli_finetune, test_nli_checkpoint

from google.colab import drive


EXPERIMENTS_PATH = '/content/drive/My Drive/PF13/nli_experiments/'
LEXICAL_MODELS_PATH = '/content/drive/My Drive/PF13/lexical_training/checkpoints-v100'


drive.mount('./drive', force_remount=True)

# %% [markdown]
# ## Baselines

# %% [markdown]
# ### ASSIN 2

# %%
run_nli_finetune(
    experiment_name='baseline-bertportuguese-assin2-3epoch',
    pretrained_model='neuralmind/bert-base-portuguese-cased',
    num_classes=2,
    train_lexical_strategy='none',
    train_dataset='assin2',
    eval_dataset='assin2',
    batch_size=32,
    max_seq_length=128,
    max_epochs=3,
    gpus=1,
    seed=123,
    output_path=EXPERIMENTS_PATH
)
# Out:
# Downloading: 100%|██████████| 647/647 [00:00<00:00, 92.0kB/s]
# Downloading:  43%|████▎     | 189M/438M [00:09<00:10, 24.1MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-13691c8a7246> in <module>
#      11     gpus=1,
#      12     seed=123,
# ---> 13     output_path=EXPERIMENTS_PATH
#      14 )
#
# ~/repositories/my/cross-lingual-transfer/crosslangt/nli/experiments.py in run_nli_finetune(experiment_name, pretrained_model, num_classes, train_lexical_strategy, train_dataset, eval_dataset, batch_size, max_seq_length, max_epochs, accumulate_grad, gpus, tpu_cores, output_path, precision, seed, tokenizer_name, experiment_version)
#     101                                  batch_size=batch_size,
#     102                                  max_seq_length=max_seq_length,
# --> 103                                  tokenizer_name=tokenizer_name)
#     104
#     105     model_checkpoint = get_model_checkpoint_callback(base_exp_path,
#
# ~/repositories/my/cross-lingual-transfer/crosslangt/nli/modeling_nli.py in __init__(self, pretrained_model, num_classes, train_lexical_strategy, train_dataset, data_dir, batch_size, max_seq_length, eval_dataset, tokenizer_name, **kwargs)
#      38
#      39         self.bert = AutoModelForSequenceClassification.from_pretrained(
# ---> 40             pretrained_model, config=self.config)
#      41
#      42         self.tokenizer = AutoTokenizer.from_pretrained(
#
# ~/.virtualenvs/deeplearning/lib/python3.6/site-packages/transformers/modeling_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     854         for config_class, model_class in MODEL_FOR_SEQUENCE_CLASSIFICATION_MAPPING.items():
#     855             if isinstance(config, config_class):
# --> 856                 return model_class.from_pretrained(pretrained_model_name_or_path, *model_args, config=config, **kwargs)
#     857         raise ValueError(
#     858             "Unrecognized configuration class {} for this kind of AutoModel: {}.\n"
#
# ~/.virtualenvs/deeplearning/lib/python3.6/site-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     633                     proxies=proxies,
#     634                     resume_download=resume_download,
# --> 635                     local_files_only=local_files_only,
#     636                 )
#     637                 if resolved_archive_file is None:
#
# ~/.virtualenvs/deeplearning/lib/python3.6/site-packages/transformers/file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, local_files_only)
#     258             resume_download=resume_download,
#     259             user_agent=user_agent,
# --> 260             local_files_only=local_files_only,
#     261         )
#     262     elif os.path.exists(url_or_filename):
#
# ~/.virtualenvs/deeplearning/lib/python3.6/site-packages/transformers/file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, local_files_only)
#     437             logger.info("%s not found in cache or force_download set to True, downloading to %s", url, temp_file.name)
#     438
# --> 439             http_get(url, temp_file, proxies=proxies, resume_size=resume_size, user_agent=user_agent)
#     440
#     441         logger.info("storing %s in cache at %s", url, cache_path)
#
# ~/.virtualenvs/deeplearning/lib/python3.6/site-packages/transformers/file_utils.py in http_get(url, temp_file, proxies, resume_size, user_agent)
#     330         disable=bool(logger.getEffectiveLevel() == logging.NOTSET),
#     331     )
# --> 332     for chunk in response.iter_content(chunk_size=1024):
#     333         if chunk:  # filter out keep-alive new chunks
#     334             progress.update(len(chunk))
#
# ~/.virtualenvs/deeplearning/lib/python3.6/site-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# ~/.virtualenvs/deeplearning/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     574         else:
#     575             while not is_fp_closed(self._fp):
# --> 576                 data = self.read(amt=amt, decode_content=decode_content)
#     577
#     578                 if data:
#
# ~/.virtualenvs/deeplearning/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# /usr/lib/python3.6/http/client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# /usr/lib/python3.6/http/client.py in readinto(self, b)
#     501         # connection, and the user is reading more bytes than will be provided
#     502         # (for example, reading in 1k chunks)
# --> 503         n = self.fp.readinto(b)
#     504         if not n and b:
#     505             # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#     999             return socket.recv(self, buflen, flags)
#    1000
# -> 1001     def recv_into(self, buffer, nbytes=None, flags=0):
#    1002         self._checkClosed()
#    1003         if buffer and (nbytes is None):
#
# KeyboardInterrupt:

# %% [markdown]
# Let's run the test with a different epoch Checkpoint:

# %% [markdown]
# #### Epoch 1

# %%
epoch1_assin2_baseline = '/content/drive/My Drive/PF13/nli_experiments/baseline-bertportuguese-assin2-3epoch/epoch=0-loss=1.04.ckpt'


test_nli_checkpoint('baseline-assin2-testset-epoch1',
                    checkpoint_path=epoch1_assin2_baseline,
                    dataset_name='assin2',
                    dataset_split='test',
                    gpus=1,
                    seed=123,
                    test_output_path=EXPERIMENTS_PATH)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# TEST RESULTS
# {'test_avg_accuracy': tensor(0.8677)}
# --------------------------------------------------------------------------------

# %% [markdown]
# #### Epoch 2

# %%
epoch2_assin2_baseline = '/content/drive/My Drive/PF13/nli_experiments/baseline-bertportuguese-assin2-3epoch/epoch=1-loss=0.12.ckpt'

test_nli_checkpoint('baseline-assin2-testset-epoch2',
                    checkpoint_path=epoch2_assin2_baseline,
                    dataset_name='assin2',
                    dataset_split='test',
                    gpus=1,
                    seed=123,
                    test_output_path=EXPERIMENTS_PATH)
# Out:
# 100%|██████████| 308k/308k [00:00<00:00, 13.3MiB/s]
# tokenizing examples: 100%|██████████| 6500/6500 [00:02<00:00, 2536.56it/s]
# tokenizing examples: 100%|██████████| 2448/2448 [00:00<00:00, 2527.81it/s]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# TEST RESULTS
# {'test_avg_accuracy': tensor(0.8827)}
# --------------------------------------------------------------------------------

# %% [markdown]
# #### Epoch 3

# %%
epoch3_assin2_baseline = '/content/drive/My Drive/PF13/nli_experiments/baseline-bertportuguese-assin2-3epoch/epoch=2-loss=0.09.ckpt'

test_nli_checkpoint('baseline-assin2-testset-epoch3',
                    checkpoint_path=epoch3_assin2_baseline,
                    dataset_name='assin2',
                    dataset_split='test',
                    gpus=1,
                    seed=123,
                    test_output_path=EXPERIMENTS_PATH)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# TEST RESULTS
# {'test_avg_accuracy': tensor(0.8803)}
# --------------------------------------------------------------------------------

# %% [markdown]
# #### ASSIN Dataset Classifier

# %%
assin2_examples = torch.load('./data/nli-assin2-eval-128.dataset')
assin2_classes = [ex.label for ex in assin2_examples]

assin2_hist = Counter(assin2_classes)
assin2_hist.most_common()
# Out:
# [(0, 1224), (1, 1224)]

# %%
(assin2_hist.most_common()[0][1] / len(assin2_examples)) * 100
# Out:
# 50.0

# %% [markdown]
# ### MNLI

# %%
run_nli_finetune(
    experiment_name='baseline-bertenglish-mnli-3epoch',
    pretrained_model='bert-base-cased',
    num_classes=3,
    train_lexical_strategy='none',
    train_dataset='mnli',
    eval_dataset='mnli',
    batch_size=32,
    max_seq_length=128,
    max_epochs=3,
    gpus=1,
    seed=123,
    output_path=EXPERIMENTS_PATH
)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=435779157.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=213450.0, style=ProgressStyle(descripti…
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]
# 100%|██████████| 313M/313M [00:04<00:00, 69.0MiB/s]
# tokenizing examples: 100%|██████████| 392702/392702 [03:31<00:00, 1859.08it/s]
# tokenizing examples: 100%|██████████| 9815/9815 [00:05<00:00, 1819.64it/s]
#
#   | Name   | Type                          | Params
# ---------------------------------------------------------
# 0 | bert   | BertForSequenceClassification | 108 M
# 1 | metric | Accuracy                      | 0
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# TEST RESULTS
# {'test_avg_accuracy': tensor(0.8255)}
# --------------------------------------------------------------------------------

# %% [markdown]
# #### Epoch 1

# %%
test_nli_checkpoint('baseline-mnli-devset-epoch1',
                    checkpoint_path='/content/drive/My Drive/PF13/nli_experiments/baseline-bertenglish-mnli-3epoch/epoch=0-loss=0.45.ckpt',
                    dataset_name='mnli',
                    dataset_split='eval',
                    gpus=1,
                    seed=123,
                    test_output_path=EXPERIMENTS_PATH)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=435779157.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=213450.0, style=ProgressStyle(descripti…
# 100%|██████████| 313M/313M [00:07<00:00, 43.5MiB/s]
# tokenizing examples: 100%|██████████| 392702/392702 [03:26<00:00, 1905.65it/s]
# tokenizing examples: 100%|██████████| 9815/9815 [00:05<00:00, 1962.69it/s]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# TEST RESULTS
# {'test_avg_accuracy': tensor(0.8255)}
# --------------------------------------------------------------------------------

# %% [markdown]
# #### Epoch 2

# %%
test_nli_checkpoint('baseline-mnli-devset-epoch2',
                    checkpoint_path='/content/drive/My Drive/PF13/nli_experiments/baseline-bertenglish-mnli-3epoch/epoch=1-loss=0.19.ckpt',
                    dataset_name='mnli',
                    dataset_split='eval',
                    gpus=1,
                    seed=123,
                    test_output_path=EXPERIMENTS_PATH)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# TEST RESULTS
# {'test_avg_accuracy': tensor(0.8159)}
# --------------------------------------------------------------------------------

# %% [markdown]
# #### Epoch 3

# %%
test_nli_checkpoint('baseline-mnli-devset-epoch3',
                    checkpoint_path='/content/drive/My Drive/PF13/nli_experiments/baseline-bertenglish-mnli-3epoch/epoch=2-loss=0.39.ckpt',
                    dataset_name='mnli',
                    dataset_split='eval',
                    gpus=1,
                    seed=123,
                    test_output_path=EXPERIMENTS_PATH)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=435779157.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=213450.0, style=ProgressStyle(descripti…
# Model parameters:
#  "batch_size":             32
# "data_dir":               ./data
# "max_seq_length":         128
# "num_classes":            3
# "pretrained_model":       bert-base-cased
# "test_dataset":           mnli
# "test_lexical_path":      None
# "test_lexical_strategy":  original
# "test_tokenizer_name":    None
# "tokenizer_name":         None
# "train_dataset":          mnli
# "train_lexical_strategy": none
# 100%|██████████| 313M/313M [00:04<00:00, 63.8MiB/s]
# tokenizing examples: 100%|██████████| 392702/392702 [03:20<00:00, 1961.34it/s]
# tokenizing examples: 100%|██████████| 9815/9815 [00:04<00:00, 2013.42it/s]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# TEST RESULTS
# {'test_avg_accuracy': tensor(0.8223)}
# --------------------------------------------------------------------------------

# %% [markdown]
# #### MNLI Dataset

# %%
mnli_examples = torch.load('./data/nli-mnli-eval-128.dataset')
mnli_classes = [ex.label for ex in mnli_examples]

mnli_histogram = Counter(mnli_classes)
mnli_histogram.most_common()
# Out:
# [(1, 3479), (2, 3213), (0, 3123)]

# %%
(mnli_histogram.most_common()[0][1] / len(mnli_examples)) * 100
# Out:
# 35.445746306673456

# %% [markdown]
# ## Finetuning the Base Model

# %%
run_nli_finetune(
    experiment_name='basemodel-lexicalfreeze-mnli-3epoch',
    pretrained_model='bert-base-cased',
    num_classes=3,
    train_lexical_strategy='freeze-all',
    train_dataset='mnli',
    eval_dataset='mnli',
    batch_size=32,
    max_seq_length=128,
    max_epochs=3,
    gpus=1,
    seed=123,
    output_path=EXPERIMENTS_PATH
)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]
#
#   | Name   | Type                          | Params
# ---------------------------------------------------------
# 0 | bert   | BertForSequenceClassification | 108 M
# 1 | metric | Accuracy                      | 0
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# TEST RESULTS
# {'test_avg_accuracy': tensor(0.8336)}
# --------------------------------------------------------------------------------

# %%
run_nli_finetune(
    experiment_name='basemodel-specialtokensfreeze-mnli-3epoch',
    pretrained_model='bert-base-cased',
    num_classes=3,
    train_lexical_strategy='freeze-nonspecial',
    train_dataset='mnli',
    eval_dataset='mnli',
    batch_size=32,
    max_seq_length=128,
    max_epochs=3,
    gpus=1,
    seed=123,
    output_path=EXPERIMENTS_PATH
)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=435779157.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=213450.0, style=ProgressStyle(descripti…
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]
# 100%|██████████| 313M/313M [00:04<00:00, 75.9MiB/s]
# tokenizing examples: 100%|██████████| 392702/392702 [03:34<00:00, 1830.21it/s]
# tokenizing examples: 100%|██████████| 9815/9815 [00:05<00:00, 1882.68it/s]
#
#   | Name   | Type                          | Params
# ---------------------------------------------------------
# 0 | bert   | BertForSequenceClassification | 108 M
# 1 | metric | Accuracy                      | 0
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-dd8aaa40daa7> in <module>()
#      13     gpus=1,
#      14     seed=123,
# ---> 15     output_path=EXPERIMENTS_PATH
#      16 )
#
# /usr/local/lib/python3.6/dist-packages/crosslangt/experiments.py in run_nli_experiment(experiment_name, pretrained_model, num_classes, train_lexical_strategy, test_lexical_strategy, test_lexical_path, train_dataset, test_dataset, batch_size, max_seq_length, max_epochs, accumulate_grad, gpus, model_checkpoint, output_path, run_training, run_test, seed, train_tokenizer_name, test_tokenizer_name)
#     125
#     126     if run_test is True:
# --> 127         trainer.test(model)
#     128
#     129
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/trainer.py in test(self, model, test_dataloaders, ckpt_path)
#    1277
#    1278         if model is not None:
# -> 1279             results = self.__test_given_model(model, test_dataloaders)
#    1280         else:
#    1281             results = self.__test_using_best_weights(ckpt_path, test_dataloaders)
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/trainer.py in __test_given_model(self, model, test_dataloaders)
#    1344         self.testing = True
#    1345         self.model = model
# -> 1346         results = self.fit(model)
#    1347         self.testing = False
#    1348
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/trainer.py in fit(self, model, train_dataloader, val_dataloaders)
#    1001
#    1002         elif self.single_gpu:
# -> 1003             results = self.single_gpu_train(model)
#    1004
#    1005         elif self.use_tpu:  # pragma: no-cover
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/distrib_parts.py in single_gpu_train(self, model)
#     169         self.setup('fit')
#     170         if self.is_function_implemented('setup', model):
# --> 171             model.setup('fit')
#     172
#     173         model.cuda(self.root_gpu)
#
# /usr/local/lib/python3.6/dist-packages/crosslangt/models.py in setup(self, stage)
#     371                 self.hparams.train_lexical_strategy,
#     372                 self.bert,
# --> 373                 self.train_tokenizer)
#     374
#     375             self.train_dataset = load_nli_dataset(
#
# /usr/local/lib/python3.6/dist-packages/crosslangt/lexical.py in setup_lexical_for_training(strategy, model, tokenizer)
#      45             bert_special_tokens_cut,
#      46             freeze_first_part=False,
# ---> 47             freeze_second_part=True)
#      48     elif strategy == 'freeze-all':
#      49         tobe_embeddings = original_embeddings
#
# /usr/local/lib/python3.6/dist-packages/crosslangt/lexical.py in slice(embedding, slice_cut, freeze_first_part, freeze_second_part)
#     194         - second: embedding.weight[slice_cut:]
#     195         """
# --> 196         weigths_a = embedding.weight[:slice_cut]
#     197         weigths_b = embedding.weight[slice_cut:]
#     198
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     592                 return modules[name]
#     593         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 594             type(self).__name__, name))
#     595
#     596     def __setattr__(self, name, value):
#
# AttributeError: 'SlicedEmbedding' object has no attribute 'weight'

# %% [markdown]
# ## Transfer Lexical
